# %% [markdown]
# # Can we make an EXPRES time series?

# %% [markdown]
# Adapted from Joe Llama (joe.llama@lowell.edu) for The Flatiron solar hack day (2023-03-15)

# %%
#%pylab notebook
from astropy.io import fits 
import matplotlib.pyplot as plt
import numpy as np
import os
import urllib.request

# %%
order = 56
bin1 = 3720
n = 400
indexs = [str(i) for i in range(5065, 5353, 1)]

# %%
R = np.zeros((len(indexs), n))
V = np.zeros(len(indexs))
for idx, index in enumerate(indexs):
    filename = f'expres/Sun_220417.{index}.fits'  
    try:
        hdu = fits.open(filename)
        w = hdu[1].data['wavelength'] # Non-excalbiur wavelength solution, NOT barycentric corrected
        s = hdu[1].data['spectrum'] # Non-normalized spectrum 
        e = hdu[1].data['uncertainty'] # Uncertainty
        c = hdu[1].data['continuum'] # Continuum model
        t = hdu[1].data['tellurics'] 
        v = hdu[2].header['HIERARCH wtd_mdpt_bc']
        R[idx, :] = (s[order, bin1:bin1+n] / c[order, bin1:bin1+n])
        V[idx] = v
    except:
        R[idx, :] = np.nan
        print(f'none on {idx}')
# Out:
# none on 12
# none on 13
# none on 27
# none on 28
# none on 43
# none on 44
# none on 59
# none on 60
# none on 75
# none on 76
# none on 92
# none on 93
# none on 108
# none on 109
# none on 123
# none on 124
# none on 136
# none on 137
# none on 150
# none on 151
# none on 169
# none on 170
# none on 188
# none on 189
# none on 207
# none on 208
# none on 226
# none on 227
# none on 244
# none on 245
# none on 262
# none on 263
# none on 279
# none on 280

# %%
for i in range(len(indexs)):
    plt.plot(R[i], color=i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/p_/61bf5lj55kzbdn4xp7f5p81r0000gn/T/ipykernel_83691/2742732091.py in <module>
#       1 for i in range(len(indexs)):
# ----> 2     plt.plot(R[i], color=i)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# --> 315             yield from self._plot_args(this, kwargs)
#     316
#     317     def get_next_color(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     537             return list(result)
#     538         else:
# --> 539             return [l[0] for l in result]
#     540
#     541
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in <listcomp>(.0)
#     537             return list(result)
#     538         else:
# --> 539             return [l[0] for l in result]
#     540
#     541
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in <genexpr>(.0)
#     530             labels = [label] * n_datasets
#     531
# --> 532         result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     533                               {**kwargs, 'label': label})
#     534                   for j, label in enumerate(labels))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     352         default_dict = self._getdefaults(set(), kw)
#     353         self._setdefaults(default_dict, kw)
# --> 354         seg = mlines.Line2D(x, y, **kw)
#     355         return seg, kw
#     356
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     372
#     373         self._color = None
# --> 374         self.set_color(color)
#     375         self._marker = MarkerStyle(marker, fillstyle)
#     376
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/lines.py in set_color(self, color)
#    1052         """
#    1053         if not cbook._str_equal(color, 'auto'):
# -> 1054             mcolors._check_color_like(color=color)
#    1055         self._color = color
#    1056         self.stale = True
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/colors.py in _check_color_like(**kwargs)
#     154     for k, v in kwargs.items():
#     155         if not is_color_like(v):
# --> 156             raise ValueError(f"{v!r} is not a valid value for {k}")
#     157
#     158
#
# ValueError: 0 is not a valid value for color

# %%
r = np.polyfit(V, R, 4)
print(r)

# %%
plt.plot(V, R)
plt.plot(V, np.poly1d(r)(V))
plt.xlabel('Vstation (z)')
plt.ylabel('Ratio')

# %%
ri = r[::-1]
cal = np.sum([i * ri[i] * V**(i-1)for i in range(len(r))], axis=0)
print(cal)
# Out:
# [ 8907.55085546  9094.50431269  9283.06277045  9472.04851319
#   9665.20472581  9859.23611327 10054.39328218 10252.45040374
#  10451.74150406 10669.87020846 10874.0914032  11073.30805471
#  11427.16075202 11625.76586789 11825.02076931 12022.22407703
#  12234.2683129  12431.79129009 12628.01125639 12826.01226663
#  13020.92579399 13214.60340697 13406.08003619 13594.21444019
#  13781.98214481 14125.32640097 14305.58943645 14484.62028301
#  14659.96068106 14833.18969652 15002.37466819 15170.77623892
#  15334.44397222 15501.59152461 15659.41112326 15814.93392138
#  15967.29462102 16113.79571191 16257.94654757 16515.81299253
#  16649.20848825 16780.25585527 16906.96600216 17028.42974786
#  17148.2225977  17264.21868197 17374.18130322 17479.95542324
#  17580.16101806 17677.29508099 17769.34913039 17857.41726166
