# %% [markdown]
# # Quick guide to EXPRES data

# %% [markdown]
# Guide by Joe Llama (joe.llama@lowell.edu) for The Flatiron solar hack day (2023-03-15)

# %%
# %pylab notebook
from astropy.io import fits 
import matplotlib.pyplot as plt
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Using one of the solar spectra as an example

# %%
hdu = fits.open('Sun_220417.5074.fits')

# %%
hdu[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# SITELONG= '-111.422515'        / East longitude site, decimal degrees
# SITELAT = '34.744305'          / Latitude of site, decimal degrees
# SITEELEV= '2337.0  '           / Elevation of observatory site (meters)
# TELESCP = 'DCT     '           / Name of telescope
# INSTRMNT= 'EXPRES  '           / Name of instrument
# DETECTOR= 'STA1600 '           / Detector type
# FPA     = 'EXPRES-D0'          / Focal Plane Array Identifier
# CNTRTYPE= 'STA-Archon'         / Detector Controller
# CNTRVRS = '1       '           / Controller firmware version
# CNTRFIRM= '/Users/expresadmin/archon/' / Location of firmware; currently a stati
# OBSERVER= 'Solar . Telescope'  / Name of observer
# OBJECT  = 'Sun     '
# OBS_ID  = '220417.5074'        / Observation ID
# PROGRAM = '201     '           / Program identifier
# RA      = '01:41:16.14'        / RA of telescope
# DEC     = '10:30:06.23'        / DEC of telescope
# FRAME   = 'FK5     '           / Frame of RA and DEC
# OBSTYPE = 'Solar   '           / Observation type
# PRESETMO= 'Solar   '           / Preset mode
# REQRA   = '01:41:16.14'        / Target right ascension
# REQDEC  = '10:30:06.23'        / Target declination
# MAXEXP  = '600     '           / Maximum exposure time
# REXPTIME= '600     '           / Requested exposure time in seconds
# HDRVRSN = '1.0     '           / See EXPRES FITS Headers Documentation.
# MIDPOINT= '2022-04-17T15:01:53.212' / Geometric midpoint btwn DATE-SHT and DATE-
# AEXPTIME= '116.16799900000316' / Actual exposure time in seconds
# EXPMTR  = 'True    '           / Exposure meter state
# AGITATOR= 'True    '           / Fiber agitator state
# ADCSTAT = 'Standing By'        / ADC Status at Beginning of Exposure
# EXPTHRES= '2500000 '           / Target signal on exposure meter
# EXPCOUNT= '2511311.0'          / Final signal on exposure meter
# CRYTEMP0= '-187.945008'        / Cryostat getter temperature
# CRYTEMP1= '-109.99996'         / Cryostat coldplate temperature
# CRYTEMP2= '-69.222728'         / Cryostat ccd temperature
# CRYPRESS= '5.901E-7'           / Cryostat pressure
# DATE-OBS= '2022-04-17 15:00:55' / Time of observation (expres_mgr shutter open t
# DATE-SHT= '2022-04-17T15:00:55.128' / Time shutter opened
# DATE-END= '2022-04-17T15:02:51.296' / Time shutter closed
# EQUNIOX = '2000    '
# CAL-TYPE= '' / Calibration type
# LAMP    = 'Off     '           / Lamp mode in calibration box
# FOC-POS = '0       '           / Current EXPRES focus motor position
# EFI-POS = '34000   '           / Current EXPRES extended flat motor position
# TELMJD  = '59686.50147512022'  / MJD of telescope ALT, AZ, and airmass
# TELALT  = '89:59:58.90'        / Altitude of telescope at TELMJD
# TELAZ   = '019:20:11.40'       / Azimuth of telescope at TELMJD
# HA      = '22:49:14.68'        / Hour angle of telescope at TELMJD
# MOONDIST= '-1      '           / Distance in degrees from the moon
# SUNDIST = '-1      '           / Distance in degrees from the sun
# AIRMASS =    2.296120984459564 / Average airmass at center of exposure
# AMBEG   =    2.312679248329877 / Airmass at beginning of exposure (TELMJD)
# AMEND   =    2.279828830511749 / Airmass at end of exposure
# CCDBIN  = '(1, 1)  '

# %%
hdu[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =               799922 / length of dimension 1
# NAXIS2  =                   86 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                   17 / number of table fields
# VERSION = '0.4.1   '           / EXPRES Pipeline code version
# EXTNAME = 'optimal '           / Extraction algorithm
# DATE-EXT= '2022-09-04T18:35:40.014' / Date and time of extraction
# SCATLGHT=                    T / Scattered light removed before extraction
# EXT_SIZE=                   33 / Size of the extraction window (pixels)
# FLAT_REL=                    T / Flat relative extracted spectral values
# EXT_BKGD=                    F / Background fit and removed during extraction
# COSMSIGM=                  8.0 / Sigma cut for cosmic rays
# COSMTAIL=                  2.0 / Sigma cut for the tails of cosmic rays
# OPT_ATOL=                1E-12 / Absolute tolerance during optimal extraction
# OPT_RTOL=                1E-10 / Relative tolerance during optimal extraction
# MAX_ITER=                 1000 / Maximum iterations during optional extraction
# CHI_DEG =                    3 / Polynomial degree when smoothing reduced chi
# DATE-WAV= '2022-09-13T03:36:57.817' / Date and time of wavelength calibration
# WAVE-CAL= 'LFC+ThAr'           / Wavelength calibration source
# INTP-PRM= 'line    '           / Wavelength interpolation parameter
# INTP-MTD= 'poly    '           / Wavelength interpolation method
# INTP-DEG=                    2 / Wavelength interpolation degree
# CONT_EXT= 'continuous'         / Extent of the approximated continuum
# CONT_FNC= 'spline  '           / Function used to fit the continuum
# CONT_DEG=                    3 / Continuum fit function degree
# CONT_RES=                100.0 / Continuum spline knot resolution
# CONT_CUT=                 -1.5 / Continuum sigma cut for absorption lines
# BARYMJD =    59686.62131385971
# WATRCOL =  -0.2180011609574985 / Telluric water column density
# AIRMASS =    2.296120984459564 / Telluric air mass
# DATE-TEL= '2022-09-29T13:03:03.404' / Date and time of telluric modeling
# DATEEXCL= '2022-10-02T17:41:11.711'
# EXCTINTP= 'local1  '
# EXCPINTP= 'pchip   '
# TTYPE1  = 'spectrum'
# TFORM1  = '7920D   '
# TTYPE2  = 'uncertainty'
# TFORM2  = '7920D   '
# TTYPE3  = 'offset  '
# TFORM3  = '7920D   '
# TTYPE4  = 'offset_uncertainty'
# TFORM4  = '7920D   '
# TTYPE5  = 'reduced_chi'
# TFORM5  = '7920D   '
# TTYPE6  = 'n_pixels'
# TFORM6  = '7920I   '
# TUNIT6  = 'pixels  '
# TTYPE7  = 'pixel_mask'
# TFORM7  = '7920L   '
# TTYPE8  = 'blaze   '
# TFORM8  = '7920D   '
# TUNIT8  = 'e-      '
# TTYPE9  = 'orders  '
# TFORM9  = 'I       '
# TTYPE10 = 'wavelength'
# TFORM10 = '7920D   '
# TUNIT10 = 'angstroms'
# TTYPE11 = 'continuum'
# TFORM11 = '7920D   '
# TTYPE12 = 'continuum_mask'
# TFORM12 = '7920L   '
# TTYPE13 = 'bary_wavelength'
# TFORM13 = '7920D   '
# TUNIT13 = 'angstroms'
# TTYPE14 = 'tellurics'
# TFORM14 = '7920D   '
# TTYPE15 = 'bary_excalibur'
# TFORM15 = '7920D   '
# TUNIT15 = 'angstroms'
# TTYPE16 = 'excalibur'
# TFORM16 = '7920D   '
# TUNIT16 = 'angstroms'
# TTYPE17 = 'excalibur_mask'
# TFORM17 = '7920L   '
# TUNIT17 = 'unitless'
# QUALITY =   0.9927320688221628

# %% [markdown]
# ## Reduced specrtra are stored in extension 1

# %% [markdown]
# Full details on the EXPRES pipeline are in Petersburg+2020: https://ui.adsabs.harvard.edu/abs/2020AJ....159..187P/abstract
#
# Wavelength solution with excalibur in Zhao+2020 https://ui.adsabs.harvard.edu/abs/2021AJ....161...80Z/abstract
#
# Telluric modeling with SELENITE in Leet+2019 https://ui.adsabs.harvard.edu/abs/2019AJ....157..187L/abstract

# %%
w = hdu[1].data['bary_excalibur'] # The best wavelength solution, available when the LFC was used. Barycentric corrected
# w = hdu[1].data['bary_wavelength'] # Non-excalbiur wavelength solution, barycentric corrected
# w = hdu[1].data['wavelength'] # Non-excalbiur wavelength solution, NOT barycentric corrected
s = hdu[1].data['spectrum'] # Non-normalized spectrum 
e = hdu[1].data['uncertainty'] # Uncertainty
c = hdu[1].data['continuum'] # Continuum model
t = hdu[1].data['tellurics'] # Selenite telluric model

# %%
nord, npix = w.shape

# %%
print("{0:d} orders, with {1:d} pixels per order".format(nord, npix))
# Out:
# 86 orders, with 7920 pixels per order

# %%
plt.figure(figsize=(9,4))
plt.plot(w[55, :], s[55, :], c='k', label='Order 55')
plt.plot(w[55, :], c[55, :], c='r', label='Continuum for 55')
plt.xlabel("Wavelength ($\AA$)")
plt.ylabel("Flux")
plt.legend(loc='lower left')
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
plt.figure(figsize=(9,4))
plt.plot(w[67, :], s[67, :] / c[67, :], c='k', label='Continuum corrected order 67')
plt.plot(w[67, :], t[67, :], c='blue', label='Telluric model for order 67')
plt.xlabel("Wavelength ($\AA$)")
plt.ylabel("Flux")
plt.legend(loc='lower right')
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# Hopeully that's enough to get going!

# %% [markdown]
# Which order has what wavelength?

# %%
for jj in range(nord):
    print(f"Order {jj:d}: {hdu[1].data['wavelength'][jj, :].min():.2f} - {hdu[1].data['wavelength'][jj, :].max():.2f} AA")
# Out:
# Order 0: 3796.64 - 3853.92 AA
# Order 1: 3820.57 - 3878.17 AA
# Order 2: 3844.81 - 3902.73 AA
# Order 3: 3869.35 - 3927.61 AA
# Order 4: 3894.21 - 3952.80 AA
# Order 5: 3919.39 - 3978.32 AA
# Order 6: 3944.89 - 4004.17 AA
# Order 7: 3970.73 - 4030.35 AA
# Order 8: 3996.90 - 4056.89 AA
# Order 9: 4023.42 - 4083.77 AA
# Order 10: 4050.30 - 4111.01 AA
# Order 11: 4077.53 - 4138.62 AA
# Order 12: 4105.13 - 4166.60 AA
# Order 13: 4133.10 - 4194.96 AA
# Order 14: 4161.46 - 4223.70 AA
# Order 15: 4190.21 - 4252.85 AA
# Order 16: 4219.36 - 4282.40 AA
# Order 17: 4248.91 - 4312.36 AA
# Order 18: 4278.88 - 4342.75 AA
# Order 19: 4309.27 - 4373.56 AA
# Order 20: 4340.10 - 4404.82 AA
# Order 21: 4371.36 - 4436.52 AA
# Order 22: 4403.09 - 4468.68 AA
# Order 23: 4435.27 - 4501.32 AA
# Order 24: 4467.93 - 4534.43 AA
# Order 25: 4501.07 - 4568.03 AA
# Order 26: 4534.70 - 4602.14 AA
# Order 27: 4568.84 - 4636.75 AA
# Order 28: 4603.49 - 4671.90 AA
# Order 29: 4638.68 - 4707.57 AA
# Order 30: 4674.40 - 4743.80 AA
# Order 31: 4710.68 - 4780.59 AA
# Order 32: 4747.52 - 4817.95 AA
# Order 33: 4784.95 - 4855.90 AA
# Order 34: 4822.96 - 4894.46 AA
# Order 35: 4861.59 - 4933.63 AA
# Order 36: 4900.84 - 4973.43 AA
# Order 37: 4940.72 - 5013.88 AA
# Order 38: 4981.26 - 5054.99 AA
# Order 39: 5022.47 - 5096.78 AA
# Order 40: 5064.36 - 5139.27 AA
# Order 41: 5106.96 - 5182.47 AA
# Order 42: 5150.27 - 5226.40 AA
# Order 43: 5194.33 - 5271.08 AA
# Order 44: 5239.15 - 5316.54 AA
# Order 45: 5284.75 - 5362.78 AA
# Order 46: 5331.14 - 5409.84 AA
# Order 47: 5378.36 - 5457.73 AA
# Order 48: 5426.42 - 5506.47 AA
# Order 49: 5475.34 - 5556.09 AA
# Order 50: 5525.16 - 5606.61 AA
# Order 51: 5575.88 - 5658.07 AA
# Order 52: 5627.55 - 5710.47 AA
# Order 53: 5680.18 - 5763.85 AA
# Order 54: 5733.80 - 5818.24 AA
# Order 55: 5788.45 - 5873.67 AA
# Order 56: 5844.14 - 5930.16 AA
# Order 57: 5900.92 - 5987.74 AA
# Order 58: 5958.81 - 6046.46 AA
# Order 59: 6017.84 - 6106.34 AA
# Order 60: 6078.06 - 6167.42 AA
# Order 61: 6139.49 - 6229.73 AA
# Order 62: 6202.17 - 6293.31 AA
# Order 63: 6266.15 - 6358.20 AA
# Order 64: 6331.45 - 6424.45 AA
# Order 65: 6398.14 - 6492.09 AA
# Order 66: 6466.24 - 6561.17 AA
# Order 67: 6535.80 - 6631.73 AA
# Order 68: 6606.88 - 6703.83 AA
# Order 69: 6679.52 - 6777.51 AA
# Order 70: 6753.77 - 6852.83 AA
# Order 71: 6829.69 - 6929.84 AA
# Order 72: 6907.33 - 7008.60 AA
# Order 73: 6986.76 - 7089.17 AA
# Order 74: 7068.04 - 7171.62 AA
# Order 75: 7151.23 - 7256.01 AA
# Order 76: 7236.39 - 7342.40 AA
# Order 77: 7323.61 - 7430.88 AA
# Order 78: 7412.96 - 7521.51 AA
# Order 79: 7504.51 - 7614.38 AA
# Order 80: 7598.35 - 7709.58 AA
# Order 81: 7694.57 - 7807.18 AA
# Order 82: 7793.25 - 7907.29 AA
# Order 83: 7894.50 - 8009.99 AA
# Order 84: 7998.41 - 8115.40 AA
# Order 85: 8105.09 - 8223.62 AA

# %%
order_no = 47
fig, ax = plt.subplots(1, figsize=(9,4))
ax.plot(w[order_no, :], s[order_no, :] / c[order_no, :], c='k', label=f'Continuum corrected order {order_no}')
ax.plot(w[order_no, :], t[order_no, :], c='blue', label=f'Telluric model for order {order_no}')
ax.set_xlabel("Wavelength ($\AA$)")
ax.set_ylabel("Flux")
ax.legend(loc='lower right')
ax.set_xlim(5400,5390)
# ax.invert_xaxis()
fig.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="900">
